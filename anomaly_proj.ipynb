# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import MinMaxScaler
from env import *
from wrangle import *
import socket

# %%
def dns_ptr_lookup(addr):
    try:
        return socket.gethostbyaddr(addr)
    except socket.herror:
        return None, None, None

# %%
df = wrangle_logs()

# %%
ip_list = []
for item in np.unique(df.ip):
    output = dns_ptr_lookup(str(item))
    ip_item = {'ip':item,
               'ip_name':output[0]}
    ip_list.append(ip_item)

# %%
ip_df = pd.DataFrame(ip_list)
df = df.merge(ip_df, left_on = 'ip', right_on = 'ip')

# %%
df.head()
# Out:
#        time                                 path  user_id  cohort_id  \
# 0  09:55:03                                    /        1        8.0
# 1  09:56:02                              java-ii        1        8.0
# 2  09:56:05  java-ii/object-oriented-programming        1        8.0
# 3  09:56:06   slides/object_oriented_programming        1        8.0
# 4  09:56:24            javascript-i/conditionals        2       22.0
#
#              ip    id   name_x     slack  start_date    end_date  \
# 0  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 1  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 2  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 3  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 4  97.105.19.61  22.0    Teddy    #teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at  deleted_at  program_id  \
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 2  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 3  2016-06-14 19:52:26  2016-06-14 19:52:26         NaN         1.0
# 4  2018-01-08 13:59:10  2018-01-08 13:59:10         NaN         2.0
#
#              datetime                            name_y
# 0 2018-01-26 09:55:03  097-105-019-061.biz.spectrum.com
# 1 2018-01-26 09:56:02  097-105-019-061.biz.spectrum.com
# 2 2018-01-26 09:56:05  097-105-019-061.biz.spectrum.com
# 3 2018-01-26 09:56:06  097-105-019-061.biz.spectrum.com
# 4 2018-01-26 09:56:24  097-105-019-061.biz.spectrum.com
